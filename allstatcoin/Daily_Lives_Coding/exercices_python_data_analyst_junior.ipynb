# %% [markdown]
# <a href="https://colab.research.google.com/github/josias76/allstatcoin/blob/main/allstatcoin/Daily_Lives_Coding/exercices_python_data_analyst_junior.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercices Python pour Data Analyst Junior
#
# Ce notebook propose une progression pratique sur :
#
# - les variables et les types de données ;
# - les opérations arithmétiques ;
# - les comparaisons et conditions ;
# - les listes ;
# - les fonctions ;
# - les exercices orientés Data Analyst ;
# - un mini-projet d'analyse des ventes.
#
# **Conseil :** essaie de résoudre chaque exercice avant de consulter un corrigé. Les cellules d'exercices sont volontairement laissées à compléter.

# %% [markdown]
# ## Niveau 1 — Variables et types de données
#
# ### Exercice 1 — Informations d'un analyste
#
# Crée des variables contenant :
#
# - ton prénom ;
# - ton âge ;
# - ton salaire souhaité ;
# - le nombre de mois d'expérience ;
# - si tu es disponible pour travailler (`True` ou `False`).
#
# Puis affiche chaque variable ainsi que son type avec `type()`.
#
# **Objectif :** `str`, `int`, `float`, `bool`, `type()`.

# %%
# @title Titre par défaut
# Écris ta solution ici
nom_p = "josias"
age_p = 30
salaire = 3000
disp = True

# %%
print("le type de la variable  nom_p est :", type(nom_p))
print("le type de la variable age_p  est :", type(age_p))
print("le type de la variable salaire est :", type(salaire))
print("le type de la variable disp  est :", type(disp))
# Out:
# le type de la variable  nom_p est : <class 'str'>
# le type de la variable age_p  est : <class 'int'>
# le type de la variable salaire est : <class 'int'>
# le type de la variable disp  est : <class 'bool'>

# %% [markdown]
# ### Exercice 2 — Fiche client
#
# On dispose des informations suivantes :
#
# ```python
# nom = "Patrick"
# age = 32
# ville = "Kinshasa"
# depenses = 1250.75
# client_actif = True
# ```
#
# 1. Affiche toutes les informations.
# 2. Affiche uniquement le nom et la ville.
# 3. Vérifie le type de chaque variable.
# 4. Modifie la ville en `"Lubumbashi"`.
# 5. Modifie les dépenses à `1500.50`.

# %%
nom = "Patrick"
age = 32
ville = "Kinshasa"
depenses = 1250.75
client_actif = True

# Écris ta solution ici

# %% [markdown]
# ### Exercice 3 — Conversion de types
#
# On récupère des données provenant d'un fichier CSV :
#
# ```python
# prix = "125.50"
# quantite = "4"
# remise = "10"
# ```
#
# 1. Transforme `prix` en `float`.
# 2. Transforme `quantite` en `int`.
# 3. Transforme `remise` en `float`.
# 4. Calcule le montant avant remise.
# 5. Calcule le montant après remise.

# %%
prix = "125.50"
quantite = "4"
remise = "10"

# Écris ta solution ici

# %% [markdown]
# ## Niveau 2 — Opérations arithmétiques
#
# ### Exercice 4 — Chiffre d'affaires
#
# Une entreprise a vendu :
#
# ```python
# prix_unitaire = 250
# quantite = 35
# ```
#
# Calcule :
#
# 1. le chiffre d'affaires ;
# 2. le montant de TVA avec un taux de 16 % ;
# 3. le chiffre d'affaires TTC.
#
# Formules :
#
# - `CA = prix × quantité`
# - `TVA = CA × taux_TVA`
# - `TTC = CA + TVA`

# %%
prix_unitaire = 250
quantite = 35
taux_tva = 0.16

# Écris ta solution ici

# %% [markdown]
# ### Exercice 5 — Analyse mensuelle
#
# Une entreprise réalise les chiffres d'affaires suivants :
#
# ```python
# janvier = 12500
# fevrier = 14800
# mars = 13200
# avril = 17100
# ```
#
# Calcule :
#
# - le CA total ;
# - le CA moyen ;
# - le CA maximum ;
# - le CA minimum ;
# - la différence entre le meilleur et le moins bon mois.
#
# **Bonus :** calcule le taux de croissance entre janvier et avril.

# %%
janvier = 12500
fevrier = 14800
mars = 13200
avril = 17100

# Écris ta solution ici

# %% [markdown]
# ### Exercice 6 — Salaire
#
# Un employé gagne :
#
# ```python
# salaire_base = 500000
# prime = 75000
# taxe = 10
# ```
#
# Calcule :
#
# 1. le salaire brut ;
# 2. le montant de la taxe ;
# 3. le salaire net.

# %%
salaire_base = 500000
prime = 75000
taxe = 10

# Écris ta solution ici

# %% [markdown]
# ## Niveau 3 — Comparaisons et conditions
#
# ### Exercice 7 — Seuil de chiffre d'affaires
#
# Une entreprise considère qu'un commercial a atteint son objectif si son CA est supérieur ou égal à `10 000 000`.
#
# À l'aide d'une condition `if`, affiche :
#
# - `Objectif atteint`
# - ou `Objectif non atteint`

# %%
ca = 12500000
objectif = 10000000

# Écris ta solution ici

# %% [markdown]
# ### Exercice 8 — Classification des clients
#
# On dispose de :
#
# ```python
# depenses = 750000
# ```
#
# Classe le client :
#
# - moins de 100 000 → `Petit client`
# - de 100 000 à 499 999 → `Client moyen`
# - de 500 000 à 999 999 → `Gros client`
# - 1 000 000 ou plus → `Client VIP`
#
# **Objectif :** pratiquer `if`, `elif`, `else`, `>=`, `<` et `and`.

# %%
depenses = 750000

# Écris ta solution ici

# %% [markdown]
# ### Exercice 9 — Contrôle qualité des données
#
# On reçoit :
#
# ```python
# age = 25
# salaire = 350000
# ```
#
# Vérifie :
#
# - si l'âge est compris entre 18 et 60 ans ;
# - si le salaire est supérieur à 200 000 ;
# - si les deux conditions sont vraies.
#
# Utilise `and`.
#
# Puis crée une deuxième vérification avec `or`.

# %%
age = 25
salaire = 350000

# Écris ta solution ici

# %% [markdown]
# ## Niveau 4 — Listes et fonctions
#
# ### Exercice 10 — Liste de ventes
#
# On dispose des ventes suivantes :
#
# ```python
# ventes = [120000, 250000, 175000, 300000, 95000, 450000]
# ```
#
# Sans utiliser de bibliothèque externe :
#
# 1. calcule le total ;
# 2. calcule la moyenne ;
# 3. trouve la vente maximale ;
# 4. trouve la vente minimale ;
# 5. compte le nombre de ventes ;
# 6. calcule l'écart entre la vente maximale et minimale.
#
# **Indice :** `sum()`, `len()`, `max()` et `min()`.

# %%
ventes = [120000, 250000, 175000, 300000, 95000, 450000]

# Écris ta solution ici

# %% [markdown]
# ### Exercice 11 — Fonction de calcul du CA
#
# Crée une fonction :
#
# ```python
# calcul_ca(prix, quantite)
# ```
#
# Elle doit retourner le chiffre d'affaires.
#
# Exemple :
#
# ```python
# calcul_ca(2500, 10)
# ```
#
# Résultat attendu : `25000`.
#
# Teste ensuite ta fonction avec plusieurs produits.

# %%
# Écris ta fonction ici


# Tests

# %% [markdown]
# ### Exercice 12 — Fonction de calcul de remise
#
# Crée une fonction :
#
# ```python
# calcul_remise(prix, taux)
# ```
#
# qui retourne le montant de la remise.
#
# Exemple :
#
# ```python
# calcul_remise(100000, 10)
# ```
#
# doit retourner `10000`.
#
# **Bonus :** crée une deuxième fonction qui retourne directement le prix après remise.

# %%
# Écris tes fonctions ici


# Tests

# %% [markdown]
# ## Niveau 5 — Exercices orientés Data Analyst
#
# ### Exercice 13 — Analyse d'un portefeuille clients
#
# Tu as les dépenses de 10 clients :
#
# ```python
# depenses = [
#     150000,
#     250000,
#     85000,
#     1200000,
#     450000,
#     75000,
#     950000,
#     300000,
#     1500000,
#     210000
# ]
# ```
#
# Réponds aux questions :
#
# 1. Combien y a-t-il de clients ?
# 2. Quel est le montant total dépensé ?
# 3. Quelle est la dépense moyenne ?
# 4. Quelle est la dépense maximale ?
# 5. Quelle est la dépense minimale ?
# 6. Combien de clients ont dépensé plus de `500000` ?
# 7. Combien ont dépensé moins de `100000` ?
# 8. Quel pourcentage des clients ont dépensé plus de `500000` ?
#
# **Objectif :** combiner variables, listes, boucles, conditions et fonctions.

# %%
depenses = [
    150000,
    250000,
    85000,
    1200000,
    450000,
    75000,
    950000,
    300000,
    1500000,
    210000
]

# Écris ta solution ici

# %% [markdown]
# ### Exercice 14 — Analyse des performances commerciales
#
# ```python
# commerciaux = ["Alice", "Paul", "Sarah", "David", "Kevin"]
#
# ca = [
#     12500000,
#     8500000,
#     15200000,
#     6200000,
#     11300000
# ]
# ```
#
# Détermine :
#
# 1. le CA total ;
# 2. le CA moyen ;
# 3. le meilleur commercial ;
# 4. son chiffre d'affaires ;
# 5. le moins performant ;
# 6. son chiffre d'affaires ;
# 7. quels commerciaux ont dépassé `10 000 000`.
#
# **Challenge :** affiche un résultat du type :
#
# ```text
# Alice : Objectif atteint
# Paul : Objectif non atteint
# Sarah : Objectif atteint
# ...
# ```

# %%
commerciaux = ["Alice", "Paul", "Sarah", "David", "Kevin"]

ca = [
    12500000,
    8500000,
    15200000,
    6200000,
    11300000
]

objectif = 10000000

# Écris ta solution ici

# %% [markdown]
# # Niveau 6 — Mini-projet Data Analyst
#
# ## Exercice 15 — Analyse des ventes d'une boutique
#
# Tu travailles comme Data Analyst pour une boutique en ligne.
#
# Voici les données :
#
# ```python
# produits = [
#     "Ordinateur",
#     "Téléphone",
#     "Casque",
#     "Clavier",
#     "Souris"
# ]
#
# prix = [
#     750000,
#     500000,
#     75000,
#     45000,
#     25000
# ]
#
# quantites = [
#     12,
#     25,
#     40,
#     35,
#     50
# ]
# ```
#
# ### Partie 1 — Calculs
#
# Pour chaque produit, calcule :
#
# `CA = prix × quantité`
#
# ### Partie 2 — KPI
#
# Calcule :
#
# - CA total ;
# - quantité totale vendue ;
# - CA moyen par produit ;
# - produit ayant généré le plus de CA ;
# - produit ayant généré le moins de CA.
#
# ### Partie 3 — Analyse
#
# Détermine :
#
# - quels produits ont généré plus de `5 000 000` ;
# - quels produits ont vendu plus de `30` unités ;
# - le pourcentage du CA total généré par chaque produit.
#
# ### Partie 4 — Fonction
#
# Crée et utilise :
#
# ```python
# calcul_ca(prix, quantite)
# ```
#
# ### Partie 5 — Challenge
#
# Crée :
#
# ```python
# analyse_produit(nom, prix, quantite)
# ```
#
# Exemple de résultat :
#
# ```text
# Produit : Ordinateur
# Prix : 750000
# Quantité : 12
# Chiffre d'affaires : 9000000
# Performance : Excellent
# ```
#
# Règles :
#
# - CA >= 5 000 000 → `Excellent`
# - CA >= 2 000 000 → `Bon`
# - CA < 2 000 000 → `Faible`

# %%
produits = [
    "Ordinateur",
    "Téléphone",
    "Casque",
    "Clavier",
    "Souris"
]

prix = [
    750000,
    500000,
    75000,
    45000,
    25000
]

quantites = [
    12,
    25,
    40,
    35,
    50
]

# Partie 1 : calcul des CA

# %%
# Partie 2 : calcul des KPI

# %%
# Partie 3 : analyse

# %%
# Partie 4 : fonction calcul_ca()

# %%
# Partie 5 : fonction analyse_produit()

# %% [markdown]
# # 🎯 Parcours recommandé
#
# Travaille dans cet ordre :
#
# 1. Exercices 1 → 3 : variables et types
# 2. Exercices 4 → 6 : calculs et opérateurs arithmétiques
# 3. Exercices 7 → 9 : comparaisons et conditions
# 4. Exercices 10 → 12 : listes et fonctions
# 5. Exercices 13 → 14 : logique d'analyse de données
# 6. Exercice 15 : mini-projet
#
# ### Méthode
#
# Pour chaque exercice :
#
# **Lire le problème → réfléchir à la logique → écrire le code → tester → corriger → vérifier.**
#
# En tant que Data Analyst, habitue-toi à te demander :
#
# - Quel est le type de ma donnée ?
# - Quelle opération dois-je effectuer ?
# - Quelle condition dois-je vérifier ?
# - Quel résultat métier est-ce que je cherche ?
